# %%
import pandas as pd

from pathlib import Path

pd.set_option('display.max_columns', None)

# %%
file_path = Path("..", "data", "alzheimers_disease_data.csv")

data = pd.read_csv(file_path,index_col='PatientID')


data.head()
# Out:
#            Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# PatientID
# 4751        73       0          0               2  22.927749        0
# 4752        89       0          0               0  26.827681        0
# 4753        73       0          3               1  17.795882        0
# 4754        74       1          0               1  33.800817        1
# 4755        89       0          0               0  20.716974        0
#
#            AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# PatientID
# 4751                13.297218          6.327112     1.347214      9.025679
# 4752                 4.542524          7.619885     0.518767      7.151293
# 4753                19.555085          7.844988     1.826335      9.673574
# 4754                12.209266          8.428001     7.435604      8.392554
# 4755                18.454356          6.310461     0.795498      5.597238
#
#            FamilyHistoryAlzheimers  CardiovascularDisease  Diabetes  \
# PatientID
# 4751                             0                      0         1
# 4752                             0                      0         0
# 4753                             1                      0         0
# 4754                             0                      0         0
# 4755                             0                      0         0
#
#            Depression  HeadInjury  Hypertension  SystolicBP  DiastolicBP  \
# PatientID
# 4751                1           0             0         142           72
# 4752                0           0             0         115           64
# 4753                0           0             0          99          116
# 4754                0           0             0         118          115
# 4755                0           0             0          94          117
#
#            CholesterolTotal  CholesterolLDL  CholesterolHDL  \
# PatientID
# 4751             242.366840       56.150897       33.682563
# 4752             231.162595      193.407996       79.028477
# 4753             284.181858      153.322762       69.772292
# 4754             159.582240       65.366637       68.457491
# 4755             237.602184       92.869700       56.874305
#
#            CholesterolTriglycerides       MMSE  FunctionalAssessment  \
# PatientID
# 4751                     162.189143  21.463532              6.518877
# 4752                     294.630909  20.613267              7.118696
# 4753                      83.638324   7.356249              5.895077
# 4754                     277.577358  13.991127              8.965106
# 4755                     291.198780  13.517609              6.045039
#
#            MemoryComplaints  BehavioralProblems       ADL  Confusion  \
# PatientID
# 4751                      0                   0  1.725883          0
# 4752                      0                   0  2.592424          0
# 4753                      0                   0  7.119548          0
# 4754                      0                   1  6.481226          0
# 4755                      0                   0  0.014691          0
#
#            Disorientation  PersonalityChanges  DifficultyCompletingTasks  \
# PatientID
# 4751                    0                   0                          1
# 4752                    0                   0                          0
# 4753                    1                   0                          1
# 4754                    0                   0                          0
# 4755                    0                   1                          1
#
#            Forgetfulness  Diagnosis DoctorInCharge
# PatientID
# 4751                   0          0      XXXConfid
# 4752                   1          0      XXXConfid
# 4753                   0          0      XXXConfid
# 4754                   0          0      XXXConfid
# 4755                   0          0      XXXConfid

# %%
# Drop the Doctor in Charge, As it is confiential data only 'XXXX' is a value
data.drop(['DoctorInCharge'],axis=1, inplace=True)

# %%
# Dictonaries of replacement data for Medical History
Gender_Dict = {0:'Male',1:'Female'}
Ethnicity_Dict = {0:'Caucasian', 1:'African American', 2:'Asian', 3:'Other'}
Education_Dict = {0:"None", 1:"High School", 2:"Bachelor's", 3: "Higher"}
Smoking_Dict = {0:'Non-Smoker', 1:'Smoker'}
FamilyHistoryAlzheimers_Dict = {0:'No Alzheimers in Family',1:'Alzheimers in Family'}
CardiovascularDisease_Dict = {0:'No Cardiovascular', 1:'Cardiovascular'}
Diabetes_Dict = {0:'No Diabetes', 1:'Diabetes'}
Depression_Dict = {0:'No Depression', 1:'Depression'}
HeadInjury_Dict = {0:'No History of Head Injury', 1: 'History of Head Injury'} 
Hypertension_Dict = {0:'Non-hypertensive', 1: 'Hypertensive'}

# %%
# Replaceing of Data for Medical History
data['Gender'].replace(to_replace=Gender_Dict,inplace=True)
data['Ethnicity'].replace(to_replace=Ethnicity_Dict,inplace=True)
data['EducationLevel'].replace(to_replace=Education_Dict,inplace=True)
data['Smoking'].replace(to_replace=Smoking_Dict,inplace=True)
data['FamilyHistoryAlzheimers'].replace(to_replace=FamilyHistoryAlzheimers_Dict,inplace=True)
data['CardiovascularDisease'].replace(to_replace=CardiovascularDisease_Dict,inplace=True)
data['Diabetes'].replace(to_replace=Diabetes_Dict,inplace=True)
data['Depression'].replace(to_replace=Depression_Dict,inplace=True)
data['HeadInjury'].replace(to_replace=HeadInjury_Dict,inplace=True)
data['Hypertension'].replace(to_replace=Hypertension_Dict,inplace=True)

data.head()
# Out:
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_15872\3679283565.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Gender'].replace(to_replace=Gender_Dict,inplace=True)
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_15872\3679283565.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Ethnicity'].replace(to_replace=Ethnicity_Dict,inplace=True)
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_15872\3679283565.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['EducationLevel'].replace(to_replace=Education_Dict,inplace=True)
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_15872\3679283565.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Smoking'].replace(to_replace=Smoking_Dict,inplace=True)
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_15872\3679283565.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['FamilyHistoryAlzheimers'].replace(to_replace=FamilyHistoryAlzheimers_Dict,inplace=True)
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_15872\3679283565.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['CardiovascularDisease'].replace(to_replace=CardiovascularDisease_Dict,inplace=True)
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_15872\3679283565.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Diabetes'].replace(to_replace=Diabetes_Dict,inplace=True)
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_15872\3679283565.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Depression'].replace(to_replace=Depression_Dict,inplace=True)
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_15872\3679283565.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['HeadInjury'].replace(to_replace=HeadInjury_Dict,inplace=True)
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_15872\3679283565.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Hypertension'].replace(to_replace=Hypertension_Dict,inplace=True)
#            Age  Gender  Ethnicity EducationLevel        BMI     Smoking  \
# PatientID
# 4751        73    Male  Caucasian     Bachelor's  22.927749  Non-Smoker
# 4752        89    Male  Caucasian           None  26.827681  Non-Smoker
# 4753        73    Male      Other    High School  17.795882  Non-Smoker
# 4754        74  Female  Caucasian    High School  33.800817      Smoker
# 4755        89    Male  Caucasian           None  20.716974  Non-Smoker
#
#            AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# PatientID
# 4751                13.297218          6.327112     1.347214      9.025679
# 4752                 4.542524          7.619885     0.518767      7.151293
# 4753                19.555085          7.844988     1.826335      9.673574
# 4754                12.209266          8.428001     7.435604      8.392554
# 4755                18.454356          6.310461     0.795498      5.597238
#
#            FamilyHistoryAlzheimers CardiovascularDisease     Diabetes  \
# PatientID
# 4751       No Alzheimers in Family     No Cardiovascular     Diabetes
# 4752       No Alzheimers in Family     No Cardiovascular  No Diabetes
# 4753          Alzheimers in Family     No Cardiovascular  No Diabetes
# 4754       No Alzheimers in Family     No Cardiovascular  No Diabetes
# 4755       No Alzheimers in Family     No Cardiovascular  No Diabetes
#
#               Depression                 HeadInjury      Hypertension  \
# PatientID
# 4751          Depression  No History of Head Injury  Non-hypertensive
# 4752       No Depression  No History of Head Injury  Non-hypertensive
# 4753       No Depression  No History of Head Injury  Non-hypertensive
# 4754       No Depression  No History of Head Injury  Non-hypertensive
# 4755       No Depression  No History of Head Injury  Non-hypertensive
#
#            SystolicBP  DiastolicBP  CholesterolTotal  CholesterolLDL  \
# PatientID
# 4751              142           72        242.366840       56.150897
# 4752              115           64        231.162595      193.407996
# 4753               99          116        284.181858      153.322762
# 4754              118          115        159.582240       65.366637
# 4755               94          117        237.602184       92.869700
#
#            CholesterolHDL  CholesterolTriglycerides       MMSE  \
# PatientID
# 4751            33.682563                162.189143  21.463532
# 4752            79.028477                294.630909  20.613267
# 4753            69.772292                 83.638324   7.356249
# 4754            68.457491                277.577358  13.991127
# 4755            56.874305                291.198780  13.517609
#
#            FunctionalAssessment  MemoryComplaints  BehavioralProblems  \
# PatientID
# 4751                   6.518877                 0                   0
# 4752                   7.118696                 0                   0
# 4753                   5.895077                 0                   0
# 4754                   8.965106                 0                   1
# 4755                   6.045039                 0                   0
#
#                 ADL  Confusion  Disorientation  PersonalityChanges  \
# PatientID
# 4751       1.725883          0               0                   0
# 4752       2.592424          0               0                   0
# 4753       7.119548          0               1                   0
# 4754       6.481226          0               0                   0
# 4755       0.014691          0               0                   1
#
#            DifficultyCompletingTasks  Forgetfulness  Diagnosis
# PatientID
# 4751                               1              0          0
# 4752                               0              1          0
# 4753                               1              0          0
# 4754                               0              0          0
# 4755                               1              0          0

# %%
# Dictonaries of replacement data for Cognitive and Functional Assessments

MemoryComplaints_Dict = {0:'No Memory Issues', 1:'Memory Complains'}
BehavioralProblems_Dict = {0:'No Behavioral Issues', 1:'Behavioral Issues'}

# %%
# Replaceing of Data for Cognitive and Functional Assessments
data['MemoryComplaints'].replace(to_replace=MemoryComplaints_Dict, inplace=True)
data['BehavioralProblems'].replace(to_replace=BehavioralProblems_Dict, inplace=True)

data.head()
# Out:
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_15872\1582021349.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['MemoryComplaints'].replace(to_replace=MemoryComplaints_Dict, inplace=True)
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_15872\1582021349.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['BehavioralProblems'].replace(to_replace=BehavioralProblems_Dict, inplace=True)
#            Age  Gender  Ethnicity EducationLevel        BMI     Smoking  \
# PatientID
# 4751        73    Male  Caucasian     Bachelor's  22.927749  Non-Smoker
# 4752        89    Male  Caucasian           None  26.827681  Non-Smoker
# 4753        73    Male      Other    High School  17.795882  Non-Smoker
# 4754        74  Female  Caucasian    High School  33.800817      Smoker
# 4755        89    Male  Caucasian           None  20.716974  Non-Smoker
#
#            AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# PatientID
# 4751                13.297218          6.327112     1.347214      9.025679
# 4752                 4.542524          7.619885     0.518767      7.151293
# 4753                19.555085          7.844988     1.826335      9.673574
# 4754                12.209266          8.428001     7.435604      8.392554
# 4755                18.454356          6.310461     0.795498      5.597238
#
#            FamilyHistoryAlzheimers CardiovascularDisease     Diabetes  \
# PatientID
# 4751       No Alzheimers in Family     No Cardiovascular     Diabetes
# 4752       No Alzheimers in Family     No Cardiovascular  No Diabetes
# 4753          Alzheimers in Family     No Cardiovascular  No Diabetes
# 4754       No Alzheimers in Family     No Cardiovascular  No Diabetes
# 4755       No Alzheimers in Family     No Cardiovascular  No Diabetes
#
#               Depression                 HeadInjury      Hypertension  \
# PatientID
# 4751          Depression  No History of Head Injury  Non-hypertensive
# 4752       No Depression  No History of Head Injury  Non-hypertensive
# 4753       No Depression  No History of Head Injury  Non-hypertensive
# 4754       No Depression  No History of Head Injury  Non-hypertensive
# 4755       No Depression  No History of Head Injury  Non-hypertensive
#
#            SystolicBP  DiastolicBP  CholesterolTotal  CholesterolLDL  \
# PatientID
# 4751              142           72        242.366840       56.150897
# 4752              115           64        231.162595      193.407996
# 4753               99          116        284.181858      153.322762
# 4754              118          115        159.582240       65.366637
# 4755               94          117        237.602184       92.869700
#
#            CholesterolHDL  CholesterolTriglycerides       MMSE  \
# PatientID
# 4751            33.682563                162.189143  21.463532
# 4752            79.028477                294.630909  20.613267
# 4753            69.772292                 83.638324   7.356249
# 4754            68.457491                277.577358  13.991127
# 4755            56.874305                291.198780  13.517609
#
#            FunctionalAssessment  MemoryComplaints    BehavioralProblems  \
# PatientID
# 4751                   6.518877  No Memory Issues  No Behavioral Issues
# 4752                   7.118696  No Memory Issues  No Behavioral Issues
# 4753                   5.895077  No Memory Issues  No Behavioral Issues
# 4754                   8.965106  No Memory Issues     Behavioral Issues
# 4755                   6.045039  No Memory Issues  No Behavioral Issues
#
#                 ADL  Confusion  Disorientation  PersonalityChanges  \
# PatientID
# 4751       1.725883          0               0                   0
# 4752       2.592424          0               0                   0
# 4753       7.119548          0               1                   0
# 4754       6.481226          0               0                   0
# 4755       0.014691          0               0                   1
#
#            DifficultyCompletingTasks  Forgetfulness  Diagnosis
# PatientID
# 4751                               1              0          0
# 4752                               0              1          0
# 4753                               1              0          0
# 4754                               0              0          0
# 4755                               1              0          0

# %%
# Dictonaries of replacement data for Symptoms

Confusion_Dict = {0: 'Not Confused', 1: 'Confused'}
Disorientation_Dict = {0: 'Not Disoriented', 1: 'Disoriented'}
PersonalityChanges_Dict = {0: 'No Personality Changes', 1: 'Personality Changes'}
DifficultyCompletingTasks_Dict = {0: 'No Difficulty', 1: 'Difficulty'}
Forgetfulness_Dict = {0: 'Not forgetful', 1: 'Forgetful'}

# %%
# Replaceing of Data for Symptoms
data['Confusion'].replace(to_replace=Confusion_Dict, inplace=True)
data['Disorientation'].replace(to_replace=Disorientation_Dict, inplace=True)
data['PersonalityChanges'].replace(to_replace=PersonalityChanges_Dict, inplace=True)
data['DifficultyCompletingTasks'].replace(to_replace=DifficultyCompletingTasks_Dict, inplace=True)
data['Forgetfulness'].replace(to_replace=Forgetfulness_Dict, inplace=True)

data.head()
# Out:
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_15872\644443541.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Confusion'].replace(to_replace=Confusion_Dict, inplace=True)
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_15872\644443541.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Disorientation'].replace(to_replace=Disorientation_Dict, inplace=True)
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_15872\644443541.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['PersonalityChanges'].replace(to_replace=PersonalityChanges_Dict, inplace=True)
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_15872\644443541.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['DifficultyCompletingTasks'].replace(to_replace=DifficultyCompletingTasks_Dict, inplace=True)
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_15872\644443541.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Forgetfulness'].replace(to_replace=Forgetfulness_Dict, inplace=True)
#            Age  Gender  Ethnicity EducationLevel        BMI     Smoking  \
# PatientID
# 4751        73    Male  Caucasian     Bachelor's  22.927749  Non-Smoker
# 4752        89    Male  Caucasian           None  26.827681  Non-Smoker
# 4753        73    Male      Other    High School  17.795882  Non-Smoker
# 4754        74  Female  Caucasian    High School  33.800817      Smoker
# 4755        89    Male  Caucasian           None  20.716974  Non-Smoker
#
#            AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# PatientID
# 4751                13.297218          6.327112     1.347214      9.025679
# 4752                 4.542524          7.619885     0.518767      7.151293
# 4753                19.555085          7.844988     1.826335      9.673574
# 4754                12.209266          8.428001     7.435604      8.392554
# 4755                18.454356          6.310461     0.795498      5.597238
#
#            FamilyHistoryAlzheimers CardiovascularDisease     Diabetes  \
# PatientID
# 4751       No Alzheimers in Family     No Cardiovascular     Diabetes
# 4752       No Alzheimers in Family     No Cardiovascular  No Diabetes
# 4753          Alzheimers in Family     No Cardiovascular  No Diabetes
# 4754       No Alzheimers in Family     No Cardiovascular  No Diabetes
# 4755       No Alzheimers in Family     No Cardiovascular  No Diabetes
#
#               Depression                 HeadInjury      Hypertension  \
# PatientID
# 4751          Depression  No History of Head Injury  Non-hypertensive
# 4752       No Depression  No History of Head Injury  Non-hypertensive
# 4753       No Depression  No History of Head Injury  Non-hypertensive
# 4754       No Depression  No History of Head Injury  Non-hypertensive
# 4755       No Depression  No History of Head Injury  Non-hypertensive
#
#            SystolicBP  DiastolicBP  CholesterolTotal  CholesterolLDL  \
# PatientID
# 4751              142           72        242.366840       56.150897
# 4752              115           64        231.162595      193.407996
# 4753               99          116        284.181858      153.322762
# 4754              118          115        159.582240       65.366637
# 4755               94          117        237.602184       92.869700
#
#            CholesterolHDL  CholesterolTriglycerides       MMSE  \
# PatientID
# 4751            33.682563                162.189143  21.463532
# 4752            79.028477                294.630909  20.613267
# 4753            69.772292                 83.638324   7.356249
# 4754            68.457491                277.577358  13.991127
# 4755            56.874305                291.198780  13.517609
#
#            FunctionalAssessment  MemoryComplaints    BehavioralProblems  \
# PatientID
# 4751                   6.518877  No Memory Issues  No Behavioral Issues
# 4752                   7.118696  No Memory Issues  No Behavioral Issues
# 4753                   5.895077  No Memory Issues  No Behavioral Issues
# 4754                   8.965106  No Memory Issues     Behavioral Issues
# 4755                   6.045039  No Memory Issues  No Behavioral Issues
#
#                 ADL     Confusion   Disorientation      PersonalityChanges  \
# PatientID
# 4751       1.725883  Not Confused  Not Disoriented  No Personality Changes
# 4752       2.592424  Not Confused  Not Disoriented  No Personality Changes
# 4753       7.119548  Not Confused      Disoriented  No Personality Changes
# 4754       6.481226  Not Confused  Not Disoriented  No Personality Changes
# 4755       0.014691  Not Confused  Not Disoriented     Personality Changes
#
#           DifficultyCompletingTasks  Forgetfulness  Diagnosis
# PatientID
# 4751                     Difficulty  Not forgetful          0
# 4752                  No Difficulty      Forgetful          0
# 4753                     Difficulty  Not forgetful          0
# 4754                  No Difficulty  Not forgetful          0
# 4755                     Difficulty  Not forgetful          0

# %%
Diagnosis_Dict = {0: "No Alzheimer's Disease", 1: "Alzheimer's Disease"}

data['Diagnosis'].replace(to_replace=Diagnosis_Dict, inplace=True)

data
# Out:
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_15872\2140441430.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Diagnosis'].replace(to_replace=Diagnosis_Dict, inplace=True)
#            Age  Gender  Ethnicity EducationLevel        BMI     Smoking  \
# PatientID
# 4751        73    Male  Caucasian     Bachelor's  22.927749  Non-Smoker
# 4752        89    Male  Caucasian           None  26.827681  Non-Smoker
# 4753        73    Male      Other    High School  17.795882  Non-Smoker
# 4754        74  Female  Caucasian    High School  33.800817      Smoker
# 4755        89    Male  Caucasian           None  20.716974  Non-Smoker
# ...        ...     ...        ...            ...        ...         ...
# 6895        61    Male  Caucasian    High School  39.121757  Non-Smoker
# 6896        75    Male  Caucasian     Bachelor's  17.857903  Non-Smoker
# 6897        77    Male  Caucasian    High School  15.476479  Non-Smoker
# 6898        78  Female      Other    High School  15.299911  Non-Smoker
# 6899        72    Male  Caucasian     Bachelor's  33.289738  Non-Smoker
#
#            AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# PatientID
# 4751                13.297218          6.327112     1.347214      9.025679
# 4752                 4.542524          7.619885     0.518767      7.151293
# 4753                19.555085          7.844988     1.826335      9.673574
# 4754                12.209266          8.428001     7.435604      8.392554
# 4755                18.454356          6.310461     0.795498      5.597238
# ...                       ...               ...          ...           ...
# 6895                 1.561126          4.049964     6.555306      7.535540
# 6896                18.767261          1.360667     2.904662      8.555256
# 6897                 4.594670          9.886002     8.120025      5.769464
# 6898                 8.674505          6.354282     1.263427      8.322874
# 6899                 7.890703          6.570993     7.941404      9.878711
#
#            FamilyHistoryAlzheimers CardiovascularDisease     Diabetes  \
# PatientID
# 4751       No Alzheimers in Family     No Cardiovascular     Diabetes
# 4752       No Alzheimers in Family     No Cardiovascular  No Diabetes
# 4753          Alzheimers in Family     No Cardiovascular  No Diabetes
# 4754       No Alzheimers in Family     No Cardiovascular  No Diabetes
# 4755       No Alzheimers in Family     No Cardiovascular  No Diabetes
# ...                            ...                   ...          ...
# 6895       No Alzheimers in Family     No Cardiovascular  No Diabetes
# 6896       No Alzheimers in Family     No Cardiovascular  No Diabetes
# 6897       No Alzheimers in Family     No Cardiovascular  No Diabetes
# 6898       No Alzheimers in Family        Cardiovascular  No Diabetes
# 6899       No Alzheimers in Family     No Cardiovascular  No Diabetes
#
#               Depression                 HeadInjury      Hypertension  \
# PatientID
# 4751          Depression  No History of Head Injury  Non-hypertensive
# 4752       No Depression  No History of Head Injury  Non-hypertensive
# 4753       No Depression  No History of Head Injury  Non-hypertensive
# 4754       No Depression  No History of Head Injury  Non-hypertensive
# 4755       No Depression  No History of Head Injury  Non-hypertensive
# ...                  ...                        ...               ...
# 6895       No Depression  No History of Head Injury  Non-hypertensive
# 6896       No Depression  No History of Head Injury  Non-hypertensive
# 6897       No Depression  No History of Head Injury  Non-hypertensive
# 6898       No Depression  No History of Head Injury  Non-hypertensive
# 6899       No Depression  No History of Head Injury  Non-hypertensive
#
#            SystolicBP  DiastolicBP  CholesterolTotal  CholesterolLDL  \
# PatientID
# 4751              142           72        242.366840       56.150897
# 4752              115           64        231.162595      193.407996
# 4753               99          116        284.181858      153.322762
# 4754              118          115        159.582240       65.366637
# 4755               94          117        237.602184       92.869700
# ...               ...          ...               ...             ...
# 6895              122          101        280.476824       94.870490
# 6896              152          106        186.384436       95.410700
# 6897              115          118        237.024558      156.267294
# 6898              103           96        242.197192       52.482961
# 6899              166           78        283.396797       92.200064
#
#            CholesterolHDL  CholesterolTriglycerides       MMSE  \
# PatientID
# 4751            33.682563                162.189143  21.463532
# 4752            79.028477                294.630909  20.613267
# 4753            69.772292                 83.638324   7.356249
# 4754            68.457491                277.577358  13.991127
# 4755            56.874305                291.198780  13.517609
# ...                   ...                       ...        ...
# 6895            60.943092                234.520123   1.201190
# 6896            93.649735                367.986877   6.458060
# 6897            99.678209                294.802338  17.011003
# 6898            81.281111                145.253746   4.030491
# 6899            81.920043                217.396873  11.114777
#
#            FunctionalAssessment  MemoryComplaints    BehavioralProblems  \
# PatientID
# 4751                   6.518877  No Memory Issues  No Behavioral Issues
# 4752                   7.118696  No Memory Issues  No Behavioral Issues
# 4753                   5.895077  No Memory Issues  No Behavioral Issues
# 4754                   8.965106  No Memory Issues     Behavioral Issues
# 4755                   6.045039  No Memory Issues  No Behavioral Issues
# ...                         ...               ...                   ...
# 6895                   0.238667  No Memory Issues  No Behavioral Issues
# 6896                   8.687480  No Memory Issues     Behavioral Issues
# 6897                   1.972137  No Memory Issues  No Behavioral Issues
# 6898                   5.173891  No Memory Issues  No Behavioral Issues
# 6899                   6.307543  No Memory Issues     Behavioral Issues
#
#                 ADL     Confusion   Disorientation      PersonalityChanges  \
# PatientID
# 4751       1.725883  Not Confused  Not Disoriented  No Personality Changes
# 4752       2.592424  Not Confused  Not Disoriented  No Personality Changes
# 4753       7.119548  Not Confused      Disoriented  No Personality Changes
# 4754       6.481226  Not Confused  Not Disoriented  No Personality Changes
# 4755       0.014691  Not Confused  Not Disoriented     Personality Changes
# ...             ...           ...              ...                     ...
# 6895       4.492838      Confused  Not Disoriented  No Personality Changes
# 6896       9.204952  Not Confused  Not Disoriented  No Personality Changes
# 6897       5.036334  Not Confused  Not Disoriented  No Personality Changes
# 6898       3.785399  Not Confused  Not Disoriented  No Personality Changes
# 6899       8.327563  Not Confused      Disoriented  No Personality Changes
#
#           DifficultyCompletingTasks  Forgetfulness               Diagnosis
# PatientID
# 4751                     Difficulty  Not forgetful  No Alzheimer's Disease
# 4752                  No Difficulty      Forgetful  No Alzheimer's Disease
# 4753                     Difficulty  Not forgetful  No Alzheimer's Disease
# 4754                  No Difficulty  Not forgetful  No Alzheimer's Disease
# 4755                     Difficulty  Not forgetful  No Alzheimer's Disease
# ...                             ...            ...                     ...
# 6895                  No Difficulty  Not forgetful     Alzheimer's Disease
# 6896                  No Difficulty  Not forgetful     Alzheimer's Disease
# 6897                  No Difficulty  Not forgetful     Alzheimer's Disease
# 6898                  No Difficulty      Forgetful     Alzheimer's Disease
# 6899                  No Difficulty      Forgetful  No Alzheimer's Disease
#
# [2149 rows x 33 columns]
