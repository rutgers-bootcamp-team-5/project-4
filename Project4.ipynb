# %%
# Import dependencies
import pandas as pd
import pyspark
import pyspark.pandas as ps

from pathlib import Path
from pyspark.shell import spark
# Out:
# c:\Users\Phil\anaconda3\envs\dev\lib\site-packages\pyspark\pandas\__init__.py:50: UserWarning: 'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.
#   warnings.warn(
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 3.5.1
#       /_/
#
# Using Python version 3.10.13 (main, Sep 11 2023 13:24:38)
# Spark context Web UI available at http://DESKTOP-DBH5AIK.mynetworksettings.com:4040
# Spark context available as 'sc' (master = local[*], app id = local-1718756654756).
# SparkSession available as 'spark'.

# %%
alzheimer_data_path = "Data/alzheimers_disease_data.csv"
alzheimer_df = pd.read_csv(alzheimer_data_path)
alzheimer_df
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0          4751   73       0          0               2  22.927749        0
# 1          4752   89       0          0               0  26.827681        0
# 2          4753   73       0          3               1  17.795882        0
# 3          4754   74       1          0               1  33.800817        1
# 4          4755   89       0          0               0  20.716974        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 2144       6895   61       0          0               1  39.121757        0
# 2145       6896   75       0          0               2  17.857903        0
# 2146       6897   77       0          0               1  15.476479        0
# 2147       6898   78       1          3               1  15.299911        0
# 2148       6899   72       0          0               2  33.289738        0
#
# ...

# %%
spark_alzheimer_df = spark.createDataFrame(alzheimer_df)
spark_alzheimer_df
# Out:
# DataFrame[PatientID: bigint, Age: bigint, Gender: bigint, Ethnicity: bigint, EducationLevel: bigint, BMI: double, Smoking: bigint, AlcoholConsumption: double, PhysicalActivity: double, DietQuality: double, SleepQuality: double, FamilyHistoryAlzheimers: bigint, CardiovascularDisease: bigint, Diabetes: bigint, Depression: bigint, HeadInjury: bigint, Hypertension: bigint, SystolicBP: bigint, DiastolicBP: bigint, CholesterolTotal: double, CholesterolLDL: double, CholesterolHDL: double, CholesterolTriglycerides: double, MMSE: double, FunctionalAssessment: double, MemoryComplaints: bigint, BehavioralProblems: bigint, ADL: double, Confusion: bigint, Disorientation: bigint, PersonalityChanges: bigint, DifficultyCompletingTasks: bigint, Forgetfulness: bigint, Diagnosis: bigint, DoctorInCharge: string]
