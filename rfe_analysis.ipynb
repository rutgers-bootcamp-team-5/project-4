# %%
import pandas as pd
import tensorflow as tf

from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

pd.set_option('display.max_columns', None)
model_results = {}

# %%
df = pd.read_csv(Path('..', 'data', 'alzheimers_disease_data.csv'))

# Drop unnecessary columns:
# PatientID:        unique identifier for each record
# DoctorInCharge:   confidential data
df.drop(columns=['PatientID', 'DoctorInCharge'], inplace=True)

# Collect remaining features
features = df.columns[:-1]

# %%
for f in features:
    drop_df = df.drop(columns=[f])

    # Split preprocessed data into features and target arrays
    X = drop_df.drop(columns='Diagnosis')
    y = drop_df['Diagnosis']

    # Split the preprocessed data into a training and testing dataset
    X_train, X_test, y_train, y_test = train_test_split(X, y)

    # Scale the data
    scaler = StandardScaler()
    X_scaler = scaler.fit(X_train)
    X_train_scaled = X_scaler.transform(X_train)
    X_test_scaled = X_scaler.transform(X_test)

    # Define the model
    nn = tf.keras.models.Sequential()
    nn.add(tf.keras.layers.Input(shape=(31,)))
    nn.add(tf.keras.layers.Dense(units=2, activation='tanh'))
    nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

    # Compile the model
    nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', 'precision', 'recall'])

    results = []
    epochs_trained = 0

    for i in range(40):
        # Train the model
        trained_model = nn.fit(
            X_train_scaled, 
            y_train, 
            epochs=5,
            verbose=0
        )

        epochs_trained += len(trained_model.epoch)

        # Evaluate the model using the test data
        metrics = nn.evaluate(X_test_scaled, y_test, verbose=0)
        results.append({
            'Epochs Trained' : epochs_trained,
            'Loss' : metrics[0],
            'Accuracy' : metrics[1],
            'Precision' : metrics[2],
            'Recall' : metrics[3]
        })

    results_df = pd.DataFrame(results)
    results_df.set_index('Epochs Trained', inplace=True)
    model_results[f'Eliminate {f}'] = results_df

# %%
results_summary = []

for name, results in model_results.items():
    results_summary.append({
        'Model' : name,
        'Loss' : results['Loss'].min(),
        'Accuracy' : results['Accuracy'].max(),
        'Precision' : results['Precision'].max(),
        'Recall' : results['Recall'].max()
    })

summary_df = pd.DataFrame(results_summary)
summary_df.set_index('Model', inplace=True)

# %%
summary_df.sort_values('Accuracy')
# Out:
#                                          Loss  Accuracy  Precision    Recall
# Model
# Eliminate ADL                        0.543745  0.732342   0.725664  0.569307
# Eliminate FunctionalAssessment       0.486673  0.754647   0.695364  0.590674
# Eliminate MemoryComplaints           0.446700  0.801115   0.765101  0.631016
# Eliminate DiastolicBP                0.429963  0.802974   0.767196  0.719807
# Eliminate BehavioralProblems         0.439100  0.806691   0.757225  0.689119
# Eliminate Age                        0.402668  0.819703   0.742690  0.751381
# Eliminate Hypertension               0.392699  0.825279   0.807229  0.722222
# Eliminate CholesterolTotal           0.397659  0.828996   0.808219  0.737374
# Eliminate MMSE                       0.409944  0.834572   0.740741  0.777778
# Eliminate DietQuality                0.376510  0.840149   0.751515  0.752941
# Eliminate Ethnicity                  0.375582  0.840149   0.834483  0.689474
# Eliminate DifficultyCompletingTasks  0.380735  0.843866   0.752688  0.792135
# Eliminate AlcoholConsumption         0.379335  0.843866   0.810056  0.774510
# Eliminate Disorientation             0.359061  0.845725   0.820000  0.779487
# Eliminate FamilyHistoryAlzheimers    0.396657  0.845725   0.803922  0.721591
# Eliminate HeadInjury                 0.394667  0.845725   0.811518  0.789216
# Eliminate CholesterolTriglycerides   0.358013  0.847584   0.836158  0.747525
# Eliminate PhysicalActivity           0.395985  0.851301   0.802395  0.745856
# Eliminate Forgetfulness              0.357426  0.851301   0.801242  0.764045
# Eliminate CholesterolHDL             0.391962  0.853160   0.815951  0.736264
# Eliminate Gender                     0.336963  0.853160   0.843373  0.788462
# Eliminate Confusion                  0.370616  0.856877   0.837349  0.757895
# Eliminate Diabetes                   0.354118  0.858736   0.850829  0.778846
# Eliminate CholesterolLDL             0.362925  0.858736   0.850000  0.757426
# Eliminate EducationLevel             0.364677  0.860595   0.848837  0.760204
# Eliminate SystolicBP                 0.379815  0.862454   0.816568  0.780220
# Eliminate CardiovascularDisease      0.368266  0.862454   0.852761  0.752632
# Eliminate SleepQuality               0.346391  0.866171   0.882759  0.721311
# Eliminate PersonalityChanges         0.362714  0.866171   0.800000  0.827957
# Eliminate BMI                        0.358819  0.869888   0.852761  0.751351
# Eliminate Smoking                    0.317209  0.871747   0.898204  0.762376
# Eliminate Depression                 0.333887  0.879182   0.832402  0.818182
